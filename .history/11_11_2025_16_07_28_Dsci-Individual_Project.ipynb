# %% [markdown]
# Research Question: We are interested in demand forecasting, namely, what time windows are most likely to have large number of simultaneous players. This is because we need to ensure that the number of licenses on hand is sufficiently large to accommodate all parallel players with high probability.

# %%
#Loading the necessary libraries for our data analysis
library(tidyverse)
library(repr)
library(tidymodels)
library(GGally)
library(ISLR)

# %% [markdown]
# (1) Data Description

# %%
#Loading Data
url_Players <- "https://github.com/rmackean/DSCI100_Individual_Project_RobM/blob/1dd6df597c248fd5e4542c13cddfb4f92f3d7628/players.csv"
url_Sessions <- "https://github.com/rmackean/DSCI100_Individual_Project_RobM/blob/1dd6df597c248fd5e4542c13cddfb4f92f3d7628/sessions.csv"
destinatio_Players <- ""

# %% [markdown]
# (1) Data Description

# %% [markdown]
# (1) Data Description

# %% [markdown]
# (1) Data Description

# %% [markdown]
# (2) Questions

# %% [markdown]
# (3) Exploratory Data Analysis and Visualization

# %% [markdown]
# (4) Methods and Plan

# %% [markdown]
# (5) GitHub Repository
